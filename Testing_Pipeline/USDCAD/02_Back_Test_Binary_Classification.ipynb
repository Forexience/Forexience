# %% [markdown]
# ## Back Test Results Binary Classification

# %%
import pandas as pd
from datetime import datetime, timezone
from pycaret.datasets import get_data
from pycaret.classification import *
import yaml
import time
import warnings
warnings.filterwarnings('ignore')

# %%
with open ('back_test_pipeline_settings.yaml') as ymlfile:
    cfg = yaml.safe_load(ymlfile)
    pair = cfg['currency']['pair']
    frac = cfg['model']['frac']
    random_state = cfg['model']['random_state']

# %%
print('Pair:', pair)
print('Fraction:', frac)
print('Random State:', random_state)
# Out:
# Pair: USDCAD
# Fraction: 0.7
# Random State: 705

# %%
now = datetime.now()
today = now.strftime("%d-%m-%Y_%I-%M_%p")

# %%
dataset = pd.read_csv('01_Back_Test_Data.csv')
dataset.shape
# Out:
# (8000, 11)

# %%
dataset.head()
# Out:
#    Candle_No  Current_Market_Fit Current_Market  Rec1_Score Rec1_Prediction  \
# 0     9194.0           42.308175        Bearish   71.071654            SELL
# 1     5507.0           33.339706        Bullish   66.961080             BUY
# 2     2777.0           43.270233        Bearish   95.938778             BUY
# 3    10079.0            0.038021        Bullish   80.800341            SELL
# 4     3476.0            6.853375        Bearish    9.044032            SELL
#
#    Rec2_Score Rec2_Prediction  Rec3_Score Rec3_Prediction  Rec4_Score  \
# 0   97.572385            SELL   28.799490            SELL   85.762444
# 1   37.886877            SELL   13.155254             BUY   81.161802
# 2    2.133071             BUY   46.326446             BUY   25.740303
# 3   64.268728            SELL   48.193146            SELL   69.665082
# 4    4.241328             BUY    8.698453            SELL   58.980401
#
#   Rec4_Prediction
# 0            SELL
# 1             BUY
# 2            SELL
# 3            SELL
# 4            SELL

# %% [markdown]
# ## Drop Predictions with Less than 20% LR Fit

# %%
dataset = dataset[dataset['Current_Market_Fit'] > 20]
dataset = dataset.reset_index()
del dataset['index']

# %%
dataset.shape
# Out:
# (5706, 11)

# %% [markdown]
# ## One-Hot Encoding

# %%
dataset['Current_Market'] = dataset['Current_Market'].replace(['Bullish','Bearish'],[1,0])
dataset['Rec1_Prediction'] = dataset['Rec1_Prediction'].replace(['BUY','SELL'],[1,-1])
dataset['Rec2_Prediction'] = dataset['Rec2_Prediction'].replace(['BUY','SELL'],[1,-1])
dataset['Rec3_Prediction'] = dataset['Rec3_Prediction'].replace(['BUY','SELL'],[1,-1])
dataset['Rec4_Prediction'] = dataset['Rec4_Prediction'].replace(['BUY','SELL'],[1,-1])

# %%
dataset['Rec1_Score'] = dataset['Rec1_Score'] * dataset['Rec1_Prediction']
dataset['Rec2_Score'] = dataset['Rec2_Score'] * dataset['Rec2_Prediction']
dataset['Rec3_Score'] = dataset['Rec3_Score'] * dataset['Rec3_Prediction']
dataset['Rec4_Score'] = dataset['Rec4_Score'] * dataset['Rec4_Prediction']

# %%
dataset['Rec1_Score'] = dataset['Rec1_Score'].round(2)
dataset['Rec2_Score'] = dataset['Rec2_Score'].round(2)
dataset['Rec3_Score'] = dataset['Rec3_Score'].round(2)
dataset['Rec4_Score'] = dataset['Rec4_Score'].round(2)

# %%
dataset = dataset.drop([
    'Candle_No',
    'Current_Market_Fit',
    'Rec1_Prediction',
    'Rec2_Prediction',
    'Rec3_Prediction',
    'Rec4_Prediction',
], axis=1)

# %%
dataset.head()
# Out:
#    Current_Market  Rec1_Score  Rec2_Score  Rec3_Score  Rec4_Score
# 0               0      -71.07      -97.57      -28.80      -85.76
# 1               1       66.96      -37.89       13.16       81.16
# 2               0       95.94        2.13       46.33      -25.74
# 3               1      -59.22        4.73       12.07      -46.19
# 4               1       54.02      -35.16      -29.36       14.96

# %%
data = dataset.sample(frac=frac, random_state=random_state).reset_index(drop=True)
data_unseen = dataset.drop(data.index).reset_index(drop=True)

print('Data for Modeling: ' + str(data.shape))
print('Unseen Data For Predictions: ' + str(data_unseen.shape))
print('Fraction: ' + str(frac))
#print('Random State: ', str(random_state))
# Out:
# Data for Modeling: (3994, 5)
# Unseen Data For Predictions: (1712, 5)
# Fraction: 0.7

# %% [markdown]
# # Create Unseen DataFrame

# %%
data_unseen.shape
# Out:
# (1712, 5)

# %%
data_unseen.head()
# Out:
#    Current_Market  Rec1_Score  Rec2_Score  Rec3_Score  Rec4_Score
# 0               1      -30.74      -77.32       -3.16      -84.20
# 1               1      -66.16        1.12       95.23       47.05
# 2               1      -85.38       86.51       72.26      -79.79
# 3               0       92.89      -12.77      -77.85      -18.07
# 4               1      -58.68        9.78      -56.22      -43.44

# %%
exp_name = setup(data = data,
                 target = 'Current_Market',
#                 fold_shuffle=True,
                 session_id=123,
                 silent=True,
#                 n_jobs = 64,
#                 imputation_type='iterative'
                )
# Out:
# <style type="text/css">
# #T_24d5a_row5_col1, #T_24d5a_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_24d5a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_24d5a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_24d5a_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_24d5a_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_24d5a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_24d5a_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_24d5a_row1_col1" class="data row1 col1" >Current_Market</td>
#     </tr>
#     <tr>
#       <th id="T_24d5a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_24d5a_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_24d5a_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_24d5a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_24d5a_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_24d5a_row3_col1" class="data row3 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_24d5a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_24d5a_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_24d5a_row4_col1" class="data row4 col1" >(3994, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_24d5a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_24d5a_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_24d5a_row5_col1" class="data row5 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_24d5a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_24d5a_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_24d5a_row6_col1" class="data row6 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_24d5a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_24d5a_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_24d5a_row7_col1" class="data row7 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_24d5a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_24d5a_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_24d5a_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_24d5a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_24d5a_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_24d5a_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_24d5a_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_24d5a_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_24d5a_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_24d5a_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_24d5a_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_24d5a_row11_col1" class="data row11 col1" >(2795, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_24d5a_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_24d5a_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_24d5a_row12_col1" class="data row12 col1" >(1199, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_24d5a_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_24d5a_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_24d5a_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_24d5a_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_24d5a_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_24d5a_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_24d5a_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_24d5a_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_24d5a_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_24d5a_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_24d5a_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_24d5a_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_24d5a_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_24d5a_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_24d5a_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_24d5a_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_24d5a_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_24d5a_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_24d5a_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_24d5a_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_24d5a_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_24d5a_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_24d5a_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_24d5a_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_24d5a_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_24d5a_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_24d5a_row21_col1" class="data row21 col1" >8be6</td>
#     </tr>
#     <tr>
#       <th id="T_24d5a_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_24d5a_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_24d5a_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_24d5a_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_24d5a_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_24d5a_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_24d5a_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_24d5a_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_24d5a_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_24d5a_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_24d5a_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_24d5a_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_24d5a_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_24d5a_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_24d5a_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_24d5a_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_24d5a_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_24d5a_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_24d5a_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_24d5a_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_24d5a_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_24d5a_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_24d5a_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_24d5a_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_24d5a_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_24d5a_row30_col0" class="data row30 col0" >Normalize Method</td>
#       <td id="T_24d5a_row30_col1" class="data row30 col1" >None</t

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_10d57_ th {
#   text-align: left;
# }
# #T_10d57_row0_col0, #T_10d57_row0_col2, #T_10d57_row0_col3, #T_10d57_row0_col5, #T_10d57_row1_col0, #T_10d57_row1_col1, #T_10d57_row1_col3, #T_10d57_row1_col4, #T_10d57_row1_col5, #T_10d57_row1_col6, #T_10d57_row1_col7, #T_10d57_row2_col0, #T_10d57_row2_col1, #T_10d57_row2_col2, #T_10d57_row2_col3, #T_10d57_row2_col4, #T_10d57_row2_col5, #T_10d57_row2_col6, #T_10d57_row2_col7, #T_10d57_row3_col0, #T_10d57_row3_col1, #T_10d57_row3_col2, #T_10d57_row3_col4, #T_10d57_row3_col6, #T_10d57_row3_col7, #T_10d57_row4_col0, #T_10d57_row4_col1, #T_10d57_row4_col2, #T_10d57_row4_col4, #T_10d57_row4_col6, #T_10d57_row4_col7, #T_10d57_row5_col0, #T_10d57_row5_col1, #T_10d57_row5_col2, #T_10d57_row5_col4, #T_10d57_row5_col6, #T_10d57_row5_col7, #T_10d57_row6_col0, #T_10d57_row6_col1, #T_10d57_row6_col2, #T_10d57_row6_col3, #T_10d57_row6_col4, #T_10d57_row6_col5, #T_10d57_row6_col6, #T_10d57_row6_col7, #T_10d57_row7_col0, #T_10d57_row7_col1, #T_10d57_row7_col2, #T_10d57_row7_col3, #T_10d57_row7_col4, #T_10d57_row7_col5, #T_10d57_row7_col6, #T_10d57_row7_col7, #T_10d57_row8_col0, #T_10d57_row8_col1, #T_10d57_row8_col2, #T_10d57_row8_col3, #T_10d57_row8_col4, #T_10d57_row8_col5, #T_10d57_row8_col6, #T_10d57_row8_col7, #T_10d57_row9_col0, #T_10d57_row9_col1, #T_10d57_row9_col2, #T_10d57_row9_col3, #T_10d57_row9_col4, #T_10d57_row9_col5, #T_10d57_row9_col6, #T_10d57_row9_col7, #T_10d57_row10_col0, #T_10d57_row10_col1, #T_10d57_row10_col2, #T_10d57_row10_col3, #T_10d57_row10_col4, #T_10d57_row10_col5, #T_10d57_row10_col6, #T_10d57_row10_col7, #T_10d57_row11_col0, #T_10d57_row11_col1, #T_10d57_row11_col2, #T_10d57_row11_col3, #T_10d57_row11_col4, #T_10d57_row11_col5, #T_10d57_row11_col6, #T_10d57_row11_col7, #T_10d57_row12_col0, #T_10d57_row12_col1, #T_10d57_row12_col2, #T_10d57_row12_col3, #T_10d57_row12_col4, #T_10d57_row12_col5, #T_10d57_row12_col6, #T_10d57_row12_col7 {
#   text-align: left;
# }
# #T_10d57_row0_col1, #T_10d57_row0_col4, #T_10d57_row0_col6, #T_10d57_row0_col7, #T_10d57_row1_col2, #T_10d57_row3_col3, #T_10d57_row3_col5, #T_10d57_row4_col3, #T_10d57_row4_col5, #T_10d57_row5_col3, #T_10d57_row5_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_10d57_row0_col8, #T_10d57_row1_col8, #T_10d57_row2_col8, #T_10d57_row3_col8, #T_10d57_row4_col8, #T_10d57_row6_col8, #T_10d57_row7_col8, #T_10d57_row8_col8, #T_10d57_row9_col8, #T_10d57_row10_col8, #T_10d57_row11_col8, #T_10d57_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_10d57_row5_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_10d57_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#       <th class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_10d57_level0_row0" class="row_heading level0 row0" >knn</th>
#       <td id="T_10d57_row0_col0" class="data row0 col0" >K Neighbors Classifier</td>
#       <td id="T_10d57_row0_col1" class="data row0 col1" >0.5242</td>
#       <td id="T_10d57_row0_col2" class="data row0 col2" >0.5245</td>
#       <td id="T_10d57_row0_col3" class="data row0 col3" >0.5552</td>
#       <td id="T_10d57_row0_col4" class="data row0 col4" >0.5321</td>
#       <td id="T_10d57_row0_col5" class="data row0 col5" >0.5430</td>
#       <td id="T_10d57_row0_col6" class="data row0 col6" >0.0472</td>
#       <td id="T_10d57_row0_col7" class="data row0 col7" >0.0472</td>
#       <td id="T_10d57_row0_col8" class="data row0 col8" >0.1740</td>
#     </tr>
#     <tr>
#       <th id="T_10d57_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_10d57_row1_col0" class="data row1 col0" >Extra Trees Classifier</td>
#       <td id="T_10d57_row1_col1" class="data row1 col1" >0.5199</td>
#       <td id="T_10d57_row1_col2" class="data row1 col2" >0.5279</td>
#       <td id="T_10d57_row1_col3" class="data row1 col3" >0.5348</td>
#       <td id="T_10d57_row1_col4" class="data row1 col4" >0.5284</td>
#       <td id="T_10d57_row1_col5" class="data row1 col5" >0.5313</td>
#       <td id="T_10d57_row1_col6" class="data row1 col6" >0.0392</td>
#       <td id="T_10d57_row1_col7" class="data row1 col7" >0.0393</td>
#       <td id="T_10d57_row1_col8" class="data row1 col8" >0.0830</td>
#     </tr>
#     <tr>
#       <th id="T_10d57_level0_row2" class="row_heading level0 row2" >dt</th>
#       <td id="T_10d57_row2_col0" class="data row2 col0" >Decision Tree Classifier</td>
#       <td id="T_10d57_row2_col1" class="data row2 col1" >0.5045</td>
#       <td id="T_10d57_row2_col2" class="data row2 col2" >0.5042</td>
#       <td id="T_10d57_row2_col3" class="data row2 col3" >0.5207</td>
#       <td id="T_10d57_row2_col4" class="data row2 col4" >0.5132</td>
#       <td id="T_10d57_row2_col5" class="data row2 col5" >0.5168</td>
#       <td id="T_10d57_row2_col6" class="data row2 col6" >0.0083</td>
#       <td id="T_10d57_row2_col7" class="data row2 col7" >0.0083</td>
#       <td id="T_10d57_row2_col8" class="data row2 col8" >0.1580</td>
#     </tr>
#     <tr>
#       <th id="T_10d57_level0_row3" class="row_heading level0 row3" >lr</th>
#       <td id="T_10d57_row3_col0" class="data row3 col0" >Logistic Regression</td>
#       <td id="T_10d57_row3_col1" class="data row3 col1" >0.5027</td>
#       <td id="T_10d57_row3_col2" class="data row3 col2" >0.4865</td>
#       <td id="T_10d57_row3_col3" class="data row3 col3" >0.7414</td>
#       <td id="T_10d57_row3_col4" class="data row3 col4" >0.5076</td>
#       <td id="T_10d57_row3_col5" class="data row3 col5" >0.6016</td>
#       <td id="T_10d57_row3_col6" class="data row3 col6" >-0.0036</td>
#       <td id="T_10d57_row3_col7" class="data row3 col7" >-0.0025</td>
#       <td id="T_10d57_row3_col8" class="data row3 col8" >0.2450</td>
#     </tr>
#     <tr>
#       <th id="T_10d57_level0_row4" class="row_heading level0 row4" >ridge</th>
#       <td id="T_10d57_row4_col0" class="data row4 col0" >Ridge Classifier</td>
#       <td id="T_10d57_row4_col1" class="data row4 col1" >0.5027</td>
#       <td id="T_10d57_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_10d57_row4_col3" class="data row4 col3" >0.7414</td>
#       <td id="T_10d57_row4_col4" class="data row4 col4" >0.5076</td>
#       <td id="T_10d57_row4_col5" class="data row4 col5" >0.6016</td>
#       <td id="T_10d57_row4_col6" class="data row4 col6" >-0.0036</td>
#       <td id="T_10d57_row4_col7" class="data row4 col7" >-0.0025</td>
#       <td id="T_10d57_row4_col8" class="data row4 col8" >0.1490</td>
#     </tr>
#     <tr>
#       <th id="T_10d57_level0_row5" class="row_heading level0 row5" >lda</th>
#       <td id="T_10d57_row5_col0" class="data row5 col0" >Linear Discriminant Analysis</td>
#       <td id="T_10d57_row5_col1" class="data row5 col1" >0.5027</td>
#       <td id="T_10d57_row5_col2" class="data row5 col2" >0.4865</td>
#       <td id="T_10d57_row5_col3" class="data row5 col3" >0.7414</td>
#       <td id="T_10d57_row5_col4" class="data row5 col4" >0.5076</td>
#       <td id="T_10d57_row5_col5" class="data row5 col5" >0.6016</td>
#       <td id="T_10d57_row5_col6" class="data row5 col6" >-0.0036</td>
#       <td id="T_10d57_row5_col7" class="data row5 col7" >-0.0025</td>
#       <td id="T_10d57_row5_col8" class="data row5 col8" >0.0060</td>
#     </tr>
#     <tr>
#       <th id="T_10d57_level0_row6" class="row_heading level0 row6" >rf</th>
#       <td id="T_10d57_row6_col0" class="data row6 col0" >Random Forest Classifier</td>
#       <td id="T_10d57_row6_col1" class="data row6 col1" >0.5016</td>
#       <td id="T_10d57_row6_col2" class="data row6 col2" >0.5099</td>
#       <td id="T_10d57_row6_col3" class=
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=-1, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
break
# Out:
#   File "/tmp/ipykernel_4558/668683560.py", line 1
#     break
#     ^
# SyntaxError: 'break' outside loop

# %%
with open ('back_test_pipeline_settings.yaml') as ymlfile:
    cfg = yaml.safe_load(ymlfile)
    model = cfg['model']['name']

# %%
print('Model Name:', model)
# Out:
# Model Name: knn

# %%
MODEL = create_model(model)
# Out:
# <style type="text/css">
# #T_603bb_row10_col0, #T_603bb_row10_col1, #T_603bb_row10_col2, #T_603bb_row10_col3, #T_603bb_row10_col4, #T_603bb_row10_col5, #T_603bb_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_603bb_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Accuracy</th>
#       <th class="col_heading level0 col1" >AUC</th>
#       <th class="col_heading level0 col2" >Recall</th>
#       <th class="col_heading level0 col3" >Prec.</th>
#       <th class="col_heading level0 col4" >F1</th>
#       <th class="col_heading level0 col5" >Kappa</th>
#       <th class="col_heading level0 col6" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_603bb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_603bb_row0_col0" class="data row0 col0" >0.5571</td>
#       <td id="T_603bb_row0_col1" class="data row0 col1" >0.5708</td>
#       <td id="T_603bb_row0_col2" class="data row0 col2" >0.5734</td>
#       <td id="T_603bb_row0_col3" class="data row0 col3" >0.5655</td>
#       <td id="T_603bb_row0_col4" class="data row0 col4" >0.5694</td>
#       <td id="T_603bb_row0_col5" class="data row0 col5" >0.1136</td>
#       <td id="T_603bb_row0_col6" class="data row0 col6" >0.1136</td>
#     </tr>
#     <tr>
#       <th id="T_603bb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_603bb_row1_col0" class="data row1 col0" >0.5357</td>
#       <td id="T_603bb_row1_col1" class="data row1 col1" >0.5289</td>
#       <td id="T_603bb_row1_col2" class="data row1 col2" >0.5524</td>
#       <td id="T_603bb_row1_col3" class="data row1 col3" >0.5448</td>
#       <td id="T_603bb_row1_col4" class="data row1 col4" >0.5486</td>
#       <td id="T_603bb_row1_col5" class="data row1 col5" >0.0707</td>
#       <td id="T_603bb_row1_col6" class="data row1 col6" >0.0707</td>
#     </tr>
#     <tr>
#       <th id="T_603bb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_603bb_row2_col0" class="data row2 col0" >0.5179</td>
#       <td id="T_603bb_row2_col1" class="data row2 col1" >0.5028</td>
#       <td id="T_603bb_row2_col2" class="data row2 col2" >0.5315</td>
#       <td id="T_603bb_row2_col3" class="data row2 col3" >0.5278</td>
#       <td id="T_603bb_row2_col4" class="data row2 col4" >0.5296</td>
#       <td id="T_603bb_row2_col5" class="data row2 col5" >0.0351</td>
#       <td id="T_603bb_row2_col6" class="data row2 col6" >0.0351</td>
#     </tr>
#     <tr>
#       <th id="T_603bb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_603bb_row3_col0" class="data row3 col0" >0.4929</td>
#       <td id="T_603bb_row3_col1" class="data row3 col1" >0.4932</td>
#       <td id="T_603bb_row3_col2" class="data row3 col2" >0.5704</td>
#       <td id="T_603bb_row3_col3" class="data row3 col3" >0.5000</td>
#       <td id="T_603bb_row3_col4" class="data row3 col4" >0.5329</td>
#       <td id="T_603bb_row3_col5" class="data row3 col5" >-0.0166</td>
#       <td id="T_603bb_row3_col6" class="data row3 col6" >-0.0167</td>
#     </tr>
#     <tr>
#       <th id="T_603bb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_603bb_row4_col0" class="data row4 col0" >0.5071</td>
#       <td id="T_603bb_row4_col1" class="data row4 col1" >0.5004</td>
#       <td id="T_603bb_row4_col2" class="data row4 col2" >0.5563</td>
#       <td id="T_603bb_row4_col3" class="data row4 col3" >0.5130</td>
#       <td id="T_603bb_row4_col4" class="data row4 col4" >0.5338</td>
#       <td id="T_603bb_row4_col5" class="data row4 col5" >0.0129</td>
#       <td id="T_603bb_row4_col6" class="data row4 col6" >0.0129</td>
#     </tr>
#     <tr>
#       <th id="T_603bb_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_603bb_row5_col0" class="data row5 col0" >0.4910</td>
#       <td id="T_603bb_row5_col1" class="data row5 col1" >0.5068</td>
#       <td id="T_603bb_row5_col2" class="data row5 col2" >0.5775</td>
#       <td id="T_603bb_row5_col3" class="data row5 col3" >0.5000</td>
#       <td id="T_603bb_row5_col4" class="data row5 col4" >0.5359</td>
#       <td id="T_603bb_row5_col5" class="data row5 col5" >-0.0211</td>
#       <td id="T_603bb_row5_col6" class="data row5 col6" >-0.0214</td>
#     </tr>
#     <tr>
#       <th id="T_603bb_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_603bb_row6_col0" class="data row6 col0" >0.5735</td>
#       <td id="T_603bb_row6_col1" class="data row6 col1" >0.5881</td>
#       <td id="T_603bb_row6_col2" class="data row6 col2" >0.5915</td>
#       <td id="T_603bb_row6_col3" class="data row6 col3" >0.5793</td>
#       <td id="T_603bb_row6_col4" class="data row6 col4" >0.5854</td>
#       <td id="T_603bb_row6_col5" class="data row6 col5" >0.1464</td>
#       <td id="T_603bb_row6_col6" class="data row6 col6" >0.1464</td>
#     </tr>
#     <tr>
#       <th id="T_603bb_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_603bb_row7_col0" class="data row7 col0" >0.4767</td>
#       <td id="T_603bb_row7_col1" class="data row7 col1" >0.4525</td>
#       <td id="T_603bb_row7_col2" class="data row7 col2" >0.4859</td>
#       <td id="T_603bb_row7_col3" class="data row7 col3" >0.4859</td>
#       <td id="T_603bb_row7_col4" class="data row7 col4" >0.4859</td>
#       <td id="T_603bb_row7_col5" class="data row7 col5" >-0.0469</td>
#       <td id="T_603bb_row7_col6" class="data row7 col6" >-0.0469</td>
#     </tr>
#     <tr>
#       <th id="T_603bb_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_603bb_row8_col0" class="data row8 col0" >0.5341</td>
#       <td id="T_603bb_row8_col1" class="data row8 col1" >0.5186</td>
#       <td id="T_603bb_row8_col2" class="data row8 col2" >0.5423</td>
#       <td id="T_603bb_row8_col3" class="data row8 col3" >0.5423</td>
#       <td id="T_603bb_row8_col4" class="data row8 col4" >0.5423</td>
#       <td id="T_603bb_row8_col5" class="data row8 col5" >0.0678</td>
#       <td id="T_603bb_row8_col6" class="data row8 col6" >0.0678</td>
#     </tr>
#     <tr>
#       <th id="T_603bb_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_603bb_row9_col0" class="data row9 col0" >0.5556</td>
#       <td id="T_603bb_row9_col1" class="data row9 col1" >0.5829</td>
#       <td id="T_603bb_row9_col2" class="data row9 col2" >0.5704</td>
#       <td id="T_603bb_row9_col3" class="data row9 col3" >0.5625</td>
#       <td id="T_603bb_row9_col4" class="data row9 col4" >0.5664</td>
#       <td id="T_603bb_row9_col5" class="data row9 col5" >0.1106</td>
#       <td id="T_603bb_row9_col6" class="data row9 col6" >0.1106</td>
#     </tr>
#     <tr>
#       <th id="T_603bb_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_603bb_row10_col0" class="data row10 col0" >0.5242</td>
#       <td id="T_603bb_row10_col1" class="data row10 col1" >0.5245</td>
#       <td id="T_603bb_row10_col2" class="data row10 col2" >0.5552</td>
#       <td id="T_603bb_row10_col3" class="data row10 col3" >0.5321</td>
#       <td id="T_603bb_row10_col4" class="data row10 col4" >0.5430</td>
#       <td id="T_603bb_row10_col5" class="data row10 col5" >0.0472</td>
#       <td id="T_603bb_row10_col6" class="data row10 col6" >0.0472</td>
#     </tr>
#     <tr>
#       <th id="T_603bb_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_603bb_row11_col0" class="data row11 col0" >0.0307</td>
#       <td id="T_603bb_row11_col1" class="data row11 col1" >0.0415</td>
#       <td id="T_603bb_row11_col2" class="data row11 col2" >0.0286</td>
#       <td id="T_603bb_row11_col3" class="data row11 col3" >0.0302</td>
#       <td id="T_603bb_row11_col4" class="data row11 col4" >0.0260</td>
#       <td id="T_603bb_row11_col5" class="data row11 col5" >0.0618</td>
#       <td id="T_603bb_row11_col6" class="data row11 col6" >0.0618</td>
#     </tr>
#   </tbody>
# </table>

# %%
plot_model(MODEL, plot = 'confusion_matrix')
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif

# %%
TUNED_MODEL = tune_model(MODEL)
# Out:
# <style type="text/css">
# #T_3a4b3_row10_col0, #T_3a4b3_row10_col1, #T_3a4b3_row10_col2, #T_3a4b3_row10_col3, #T_3a4b3_row10_col4, #T_3a4b3_row10_col5, #T_3a4b3_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_3a4b3_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Accuracy</th>
#       <th class="col_heading level0 col1" >AUC</th>
#       <th class="col_heading level0 col2" >Recall</th>
#       <th class="col_heading level0 col3" >Prec.</th>
#       <th class="col_heading level0 col4" >F1</th>
#       <th class="col_heading level0 col5" >Kappa</th>
#       <th class="col_heading level0 col6" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3a4b3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3a4b3_row0_col0" class="data row0 col0" >0.5571</td>
#       <td id="T_3a4b3_row0_col1" class="data row0 col1" >0.5655</td>
#       <td id="T_3a4b3_row0_col2" class="data row0 col2" >0.6014</td>
#       <td id="T_3a4b3_row0_col3" class="data row0 col3" >0.5621</td>
#       <td id="T_3a4b3_row0_col4" class="data row0 col4" >0.5811</td>
#       <td id="T_3a4b3_row0_col5" class="data row0 col5" >0.1125</td>
#       <td id="T_3a4b3_row0_col6" class="data row0 col6" >0.1128</td>
#     </tr>
#     <tr>
#       <th id="T_3a4b3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3a4b3_row1_col0" class="data row1 col0" >0.5607</td>
#       <td id="T_3a4b3_row1_col1" class="data row1 col1" >0.5351</td>
#       <td id="T_3a4b3_row1_col2" class="data row1 col2" >0.5315</td>
#       <td id="T_3a4b3_row1_col3" class="data row1 col3" >0.5758</td>
#       <td id="T_3a4b3_row1_col4" class="data row1 col4" >0.5527</td>
#       <td id="T_3a4b3_row1_col5" class="data row1 col5" >0.1225</td>
#       <td id="T_3a4b3_row1_col6" class="data row1 col6" >0.1229</td>
#     </tr>
#     <tr>
#       <th id="T_3a4b3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3a4b3_row2_col0" class="data row2 col0" >0.4857</td>
#       <td id="T_3a4b3_row2_col1" class="data row2 col1" >0.4978</td>
#       <td id="T_3a4b3_row2_col2" class="data row2 col2" >0.5734</td>
#       <td id="T_3a4b3_row2_col3" class="data row2 col3" >0.4970</td>
#       <td id="T_3a4b3_row2_col4" class="data row2 col4" >0.5325</td>
#       <td id="T_3a4b3_row2_col5" class="data row2 col5" >-0.0325</td>
#       <td id="T_3a4b3_row2_col6" class="data row2 col6" >-0.0329</td>
#     </tr>
#     <tr>
#       <th id="T_3a4b3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3a4b3_row3_col0" class="data row3 col0" >0.5000</td>
#       <td id="T_3a4b3_row3_col1" class="data row3 col1" >0.4994</td>
#       <td id="T_3a4b3_row3_col2" class="data row3 col2" >0.5352</td>
#       <td id="T_3a4b3_row3_col3" class="data row3 col3" >0.5067</td>
#       <td id="T_3a4b3_row3_col4" class="data row3 col4" >0.5205</td>
#       <td id="T_3a4b3_row3_col5" class="data row3 col5" >-0.0010</td>
#       <td id="T_3a4b3_row3_col6" class="data row3 col6" >-0.0010</td>
#     </tr>
#     <tr>
#       <th id="T_3a4b3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3a4b3_row4_col0" class="data row4 col0" >0.5250</td>
#       <td id="T_3a4b3_row4_col1" class="data row4 col1" >0.5116</td>
#       <td id="T_3a4b3_row4_col2" class="data row4 col2" >0.6268</td>
#       <td id="T_3a4b3_row4_col3" class="data row4 col3" >0.5266</td>
#       <td id="T_3a4b3_row4_col4" class="data row4 col4" >0.5723</td>
#       <td id="T_3a4b3_row4_col5" class="data row4 col5" >0.0472</td>
#       <td id="T_3a4b3_row4_col6" class="data row4 col6" >0.0481</td>
#     </tr>
#     <tr>
#       <th id="T_3a4b3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3a4b3_row5_col0" class="data row5 col0" >0.5161</td>
#       <td id="T_3a4b3_row5_col1" class="data row5 col1" >0.4929</td>
#       <td id="T_3a4b3_row5_col2" class="data row5 col2" >0.5563</td>
#       <td id="T_3a4b3_row5_col3" class="data row5 col3" >0.5232</td>
#       <td id="T_3a4b3_row5_col4" class="data row5 col4" >0.5392</td>
#       <td id="T_3a4b3_row5_col5" class="data row5 col5" >0.0308</td>
#       <td id="T_3a4b3_row5_col6" class="data row5 col6" >0.0309</td>
#     </tr>
#     <tr>
#       <th id="T_3a4b3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3a4b3_row6_col0" class="data row6 col0" >0.5448</td>
#       <td id="T_3a4b3_row6_col1" class="data row6 col1" >0.5517</td>
#       <td id="T_3a4b3_row6_col2" class="data row6 col2" >0.5634</td>
#       <td id="T_3a4b3_row6_col3" class="data row6 col3" >0.5517</td>
#       <td id="T_3a4b3_row6_col4" class="data row6 col4" >0.5575</td>
#       <td id="T_3a4b3_row6_col5" class="data row6 col5" >0.0890</td>
#       <td id="T_3a4b3_row6_col6" class="data row6 col6" >0.0890</td>
#     </tr>
#     <tr>
#       <th id="T_3a4b3_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3a4b3_row7_col0" class="data row7 col0" >0.4803</td>
#       <td id="T_3a4b3_row7_col1" class="data row7 col1" >0.4766</td>
#       <td id="T_3a4b3_row7_col2" class="data row7 col2" >0.4859</td>
#       <td id="T_3a4b3_row7_col3" class="data row7 col3" >0.4894</td>
#       <td id="T_3a4b3_row7_col4" class="data row7 col4" >0.4876</td>
#       <td id="T_3a4b3_row7_col5" class="data row7 col5" >-0.0396</td>
#       <td id="T_3a4b3_row7_col6" class="data row7 col6" >-0.0396</td>
#     </tr>
#     <tr>
#       <th id="T_3a4b3_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3a4b3_row8_col0" class="data row8 col0" >0.5269</td>
#       <td id="T_3a4b3_row8_col1" class="data row8 col1" >0.5439</td>
#       <td id="T_3a4b3_row8_col2" class="data row8 col2" >0.5563</td>
#       <td id="T_3a4b3_row8_col3" class="data row8 col3" >0.5338</td>
#       <td id="T_3a4b3_row8_col4" class="data row8 col4" >0.5448</td>
#       <td id="T_3a4b3_row8_col5" class="data row8 col5" >0.0527</td>
#       <td id="T_3a4b3_row8_col6" class="data row8 col6" >0.0528</td>
#     </tr>
#     <tr>
#       <th id="T_3a4b3_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_3a4b3_row9_col0" class="data row9 col0" >0.5591</td>
#       <td id="T_3a4b3_row9_col1" class="data row9 col1" >0.5727</td>
#       <td id="T_3a4b3_row9_col2" class="data row9 col2" >0.5775</td>
#       <td id="T_3a4b3_row9_col3" class="data row9 col3" >0.5655</td>
#       <td id="T_3a4b3_row9_col4" class="data row9 col4" >0.5714</td>
#       <td id="T_3a4b3_row9_col5" class="data row9 col5" >0.1177</td>
#       <td id="T_3a4b3_row9_col6" class="data row9 col6" >0.1177</td>
#     </tr>
#     <tr>
#       <th id="T_3a4b3_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_3a4b3_row10_col0" class="data row10 col0" >0.5256</td>
#       <td id="T_3a4b3_row10_col1" class="data row10 col1" >0.5247</td>
#       <td id="T_3a4b3_row10_col2" class="data row10 col2" >0.5608</td>
#       <td id="T_3a4b3_row10_col3" class="data row10 col3" >0.5332</td>
#       <td id="T_3a4b3_row10_col4" class="data row10 col4" >0.5460</td>
#       <td id="T_3a4b3_row10_col5" class="data row10 col5" >0.0499</td>
#       <td id="T_3a4b3_row10_col6" class="data row10 col6" >0.0501</td>
#     </tr>
#     <tr>
#       <th id="T_3a4b3_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_3a4b3_row11_col0" class="data row11 col0" >0.0285</td>
#       <td id="T_3a4b3_row11_col1" class="data row11 col1" >0.0317</td>
#       <td id="T_3a4b3_row11_col2" class="data row11 col2" >0.0369</td>
#       <td id="T_3a4b3_row11_col3" class="data row11 col3" >0.0285</td>
#       <td id="T_3a4b3_row11_col4" class="data row11 col4" >0.0265</td>
#       <td id="T_3a4b3_row11_col5" class="data row11 col5" >0.0575</td>
#       <td id="T_3a4b3_row11_col6" class="data row11 col6" >0.0577</td>
#     </tr>
#   </tbody>
# </table>

# %%
plot_model(TUNED_MODEL, plot = 'auc')
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif

# %%
plot_model(TUNED_MODEL, plot = 'pr')

# %%
plot_model(TUNED_MODEL, plot='feature')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_4558/4038538239.py in <module>
# ----> 1 plot_model(TUNED_MODEL, plot='feature')
#
# ~/Data/Forexience/venv/lib/python3.8/site-packages/pycaret/classification.py in plot_model(estimator, plot, scale, save, fold, fit_kwargs, groups, use_train_data, verbose, display_format)
#    1538     """
#    1539
# -> 1540     return pycaret.internal.tabular.plot_model(
#    1541         estimator=estimator,
#    1542         plot=plot,
#
# ~/Data/Forexience/venv/lib/python3.8/site-packages/pycaret/internal/tabular.py in plot_model(estimator, plot, scale, save, fold, fit_kwargs, groups, feature_name, label, use_train_data, verbose, system, display, display_format, is_in_evaluate)
#    5864         hasattr(estimator, "coef_") or hasattr(estimator, "feature_importances_")
#    5865     ) and (plot == "feature" or plot == "feature_all" or plot == "rfe"):
# -> 5866         raise TypeError(
#    5867             "Feature Importance and RFE plots not available for estimators that doesnt support coef_ or feature_importances_ attribute."
#    5868         )
#
# TypeError: Feature Importance and RFE plots not available for estimators that doesnt support coef_ or feature_importances_ attribute.

# %%
plot_model(TUNED_MODEL, plot = 'confusion_matrix')

# %%
predict_model(TUNED_MODEL);
# Out:
# <style type="text/css">
# </style>
# <table id="T_a4068_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a4068_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a4068_row0_col0" class="data row0 col0" >K Neighbors Classifier</td>
#       <td id="T_a4068_row0_col1" class="data row0 col1" >0.4871</td>
#       <td id="T_a4068_row0_col2" class="data row0 col2" >0.4768</td>
#       <td id="T_a4068_row0_col3" class="data row0 col3" >0.5179</td>
#       <td id="T_a4068_row0_col4" class="data row0 col4" >0.5008</td>
#       <td id="T_a4068_row0_col5" class="data row0 col5" >0.5092</td>
#       <td id="T_a4068_row0_col6" class="data row0 col6" >-0.0276</td>
#       <td id="T_a4068_row0_col7" class="data row0 col7" >-0.0276</td>
#     </tr>
#   </tbody>
# </table>

# %%
FINAL_MODEL = finalize_model(TUNED_MODEL)

# %%
print(FINAL_MODEL)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='euclidean',
#                      metric_params=None, n_jobs=-1, n_neighbors=12, p=2,
#                      weights='distance')

# %%
predict_model(FINAL_MODEL);
# Out:
# <style type="text/css">
# </style>
# <table id="T_f34d8_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f34d8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f34d8_row0_col0" class="data row0 col0" >K Neighbors Classifier</td>
#       <td id="T_f34d8_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_f34d8_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_f34d8_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_f34d8_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_f34d8_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_f34d8_row0_col6" class="data row0 col6" >1.0000</td>
#       <td id="T_f34d8_row0_col7" class="data row0 col7" >1.0000</td>
#     </tr>
#   </tbody>
# </table>

# %%
unseen_predictions = predict_model(FINAL_MODEL, data=data_unseen)
unseen_predictions.head()
# Out:
#    Current_Market  Rec1_Score  Rec2_Score  Rec3_Score  Rec4_Score  Label  \
# 0               1      -30.74      -77.32       -3.16      -84.20      1
# 1               1      -66.16        1.12       95.23       47.05      1
# 2               1      -85.38       86.51       72.26      -79.79      1
# 3               0       92.89      -12.77      -77.85      -18.07      0
# 4               1      -58.68        9.78      -56.22      -43.44      1
#
#     Score
# 0  1.0000
# 1  0.6445
# 2  1.0000
# 3  1.0000
# 4  0.5137

# %%
plot_model(FINAL_MODEL, plot = 'auc')

# %%
pkl_name = (today + "_" + model + "_" + pair)

# %%
save_model(FINAL_MODEL, pkl_name)
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=False, features_todrop=[],
#                                        id_columns=[],
#                                        ml_usecase='classification',
#                                        numerical_features=[],
#                                        target='Current_Market',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  nume...
#                  ('fix_perfect', Remove_100(target='Current_Market')),
#                  ('clean_names', Clean_Colum_Names()),
#                  ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                  ('dfs', 'passthrough'), ('pca', 'passthrough'),
#                  ['trained_model',
#                   KNeighborsClassifier(algorithm='auto', leaf_size=30,
#                                        metric='euclidean', metric_params=None,
#                                        n_jobs=-1, n_neighbors=12, p=2,
#                                        weights='distance')]],
#           verbose=False),
#  '23-01-2022_01-24_AM_knn_USDCAD.pkl')

# %%
SAVED_FINAL_MODEL = load_model(pkl_name)
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
new_prediction = predict_model(SAVED_FINAL_MODEL, data=data_unseen)

# %%
data_unseen.shape
# Out:
# (1712, 5)

# %%
new_prediction.head(20)
# Out:
#     Current_Market  Rec1_Score  Rec2_Score  Rec3_Score  Rec4_Score  Label  \
# 0                1      -30.74      -77.32       -3.16      -84.20      1
# 1                1      -66.16        1.12       95.23       47.05      1
# 2                1      -85.38       86.51       72.26      -79.79      1
# 3                0       92.89      -12.77      -77.85      -18.07      0
# 4                1      -58.68        9.78      -56.22      -43.44      1
# 5                0      -20.94       -3.04      -29.72      -39.15      0
# 6                0      -58.77       20.39      -51.22       77.80      1
# 7                0       -0.08       12.79       87.87       48.43      0
# 8                1       42.26      -82.14      -31.31        0.32      1
# 9                0      -62.55      -86.64      -86.46      -93.95      0
# 10               0       71.99       64.83      -31.31        0.32      0
# 11               0       20.93      -36.50      -53.88       79.40      0
# 12               1      -61.46      -53.84      -37.50       72.04      1
# 13               1       -1.52        7.61      -55.35       45.01      1
# 14               0        0.77       65.33       67.00       60.57      0
# 15               0       37.06      -93.67      -63.77      -37.17      1
# 16               1      -13.85       58.48      -44.26       47.63      0
# 17               0        3.10      -87.44       15.00       40.77      0
# 18               1       -0.86        0.02       -2.45       -7.78      0
# 19               0      -38.81        5.80       74.57       74.96      0
#
#      Score
# 0   1.0000
# 1   0.6445
# 2   1.0000
# 3   1.0000
# 4   0.5137
# 5   1.0000
# 6   0.5471
# 7   0.7037
# 8   1.0000
# 9   1.0000
# 10  0.6498
# 11  1.0000
# 12  0.6332
# 13  1.0000
# 14  1.0000
# 15  0.5912
# 16  0.5031
# 17  1.0000
# 18  0.5363
# 19  1.0000

# %%
file = open(today + "_" + model + "_binary_classification_log_" + pair + ".txt", "w")
file.write ("Date: " + today + "\n" + \
            "Currency Pair: " + pair + "\n" + \
            "Model: " + model + "\n" + \
            "Frac: " + str(frac) + "\n" + \
            "Random State: " + str(random_state) + "\n" )
file.close()
# Out:
# /home/mladmin/Data/Forexience/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/mladmin/Data/Forexience/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/mladmin/Data/Forexience/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/mladmin/Data/Forexience/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/mladmin/Data/Forexience/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/mladmin/Data/Forexience/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/mladmin/Data/Forexience/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/mladmin/Data/Forexience/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/mladmin/Data/Forexience/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/mladmin/Data/Forexience/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/mladmin/Data/Forexience/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/mladmin/Data/Forexience/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/mladmin/Data/Forexience/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/mladmin/Data/Forexience/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/mladmin/Data/Forexience/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/mladmin/Data/Forexience/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/mladmin/Data/Forexience/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/mladmin/Data/Forexience/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/mladmin/Data/Forexience/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/mladmin/Data/Forexience/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/mladmin/Data/Forexience/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/mladmin/Data/Forexience/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/mladmin/Data/Forexience/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/mladmin/Data/Forexience/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/mladmin/Data/Forexience/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/mladmin/Data/Forexience/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/mladmin/Data/Forexience/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/mladmin/Data/Forexience/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/mladmin/Data/Forexience/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/mladmin/Data/Forexience/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/mladmin/Data/Forexience/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/mladmin/Data/Forexience/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/mladmin/Data/Forexience/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/mladmin/Data/Forexience/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/mladmin/Data/Forexience/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/mladmin/Data/Forexience/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/mladmin/Data/Forexience/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/mladmin/Data/Forexience/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/mladmin/Data/Forexience/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/mladmin/Data/Forexience/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
